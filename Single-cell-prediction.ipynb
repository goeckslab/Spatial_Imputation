# %%
import os
import re 
import numpy as np 
import pandas as pd 
import anndata as ad

# %%
#
# Read in TMA cell data.
#
data_dir = './TMA1_004/TMA1_004_h5ad'

# Load the data.
adatas = {}

# iterate through the file names in the input folder 
for fh in os.listdir(data_dir):

    # ignore any hidden or other non data files 
    if fh.endswith('h5ad'):

        # isolate the core name from the file name using a series of regular expressions
        # the expressions might have to change depending on which slide you use 
        initial_split = re.split('\.', fh)[0]
        core_ID = re.split('-', initial_split)[-1]

        # read the file as anndata object, save in dictionary, {core_ID : adata}
        adatas[core_ID] = ad.read_h5ad(os.path.join(data_dir, fh))
# Out:
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
adatas
# Out:
# {'C2': AnnData object with n_obs × n_vars = 9285 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'F7': AnnData object with n_obs × n_vars = 6368 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'C5': AnnData object with n_obs × n_vars = 9666 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'G5': AnnData object with n_obs × n_vars = 18567 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'B7': AnnData object with n_obs × n_vars = 7336 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'G2': AnnData object with n_obs × n_vars = 5917 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'A1': AnnData object with n_obs × n_vars = 18929 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'D4': AnnData object with n_obs × n_vars = 11362 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'A6': AnnData object with n_obs × n_vars = 4565 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'D3': AnnData object with n_obs × n_vars = 8709 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'E6': AnnData object with n_obs × n_vars = 13915 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'E1': AnnData object with n_obs × n_vars = 22803 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'G3': AnnData object with n_obs × n_vars = 18596 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'B6': AnnData object with n_obs × n_vars = 14263 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'G4': AnnData object with n_obs × n_vars = 2753 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'B1': AnnData object with n_obs × n_vars = 6199 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'F1': AnnData object with n_obs × n_vars = 16573 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'C4': AnnData object with n_obs × n_vars = 3238 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'F6': AnnData object with n_obs × n_vars = 2918 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'C3': AnnData object with n_obs × n_vars = 3007 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'E7': AnnData object with n_obs × n_vars = 14644 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'D2': AnnData object with n_obs × n_vars = 8358 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'A7': AnnData object with n_obs × n_vars = 10523 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'D5': AnnData object with n_obs × n_vars = 2700 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'D8': AnnData object with n_obs × n_vars = 3142 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'C9': AnnData object with n_obs × n_vars = 18908 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'H1': AnnData object with n_obs × n_vars = 1740 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'G9': AnnData object with n_obs × n_vars = 9060 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'H6': AnnData object with n_obs × n_vars = 3821 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'D9': AnnData object with n_obs × n_vars = 2303 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'H7': AnnData object with n_obs × n_vars = 8769 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'G8': AnnData object with n_obs × n_vars = 4234 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'C8': AnnData object with n_obs × n_vars = 4425 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'C10': AnnData object with n_obs × n_vars = 11469 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'E11': AnnData object with n_obs × n_vars = 8021 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'E9': AnnData object with n_obs × n_vars = 10318 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'A9': AnnData object with n_obs × n_vars = 1280 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'H2': AnnData object with n_obs × n_vars = 7901 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'B8': AnnData object with n_obs × n_vars = 397 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'B11': AnnData object with n_obs × n_vars = 12234 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'D10': AnnData object with n_obs × n_vars = 3540 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'H5': AnnData object with n_obs × n_vars = 475 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'F8': AnnData object with n_obs × n_vars = 4796 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'A8': AnnData object with n_obs × n_vars = 13078 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'E8': AnnData object with n_obs × n_vars = 7994 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'E10': AnnData object with n_obs × n_vars = 10692 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'C11': AnnData object with n_obs × n_vars = 3375 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'F9': AnnData object with n_obs × n_vars = 17911 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'D11': AnnData object with n_obs × n_vars = 3696 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'H4': AnnData object with n_obs × n_vars = 17663 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'B10': AnnData object with n_obs × n_vars = 6686 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'B9': AnnData object with n_obs × n_vars = 6184 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'H3': AnnData object with n_obs × n_vars = 10696 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'H9': AnnData object with n_obs × n_vars = 10897 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'B3': AnnData object with n_obs × n_vars = 12566 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'G6': AnnData object with n_obs × n_vars = 10343 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'B4': AnnData object with n_obs × n_vars = 10248 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'G1': AnnData object with n_obs × n_vars = 16132 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'H10': AnnData object with n_obs × n_vars = 11203 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'F11': AnnData object with n_obs × n_vars = 13671 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'C1': AnnData object with n_obs × n_vars = 4157 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'F4': AnnData object with n_obs × n_vars = 9048 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'C6': AnnData object with n_obs × n_vars = 1616 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'F3': AnnData object with n_obs × n_vars = 6591 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'E5': AnnData object with n_obs × n_vars = 15500 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'E2': AnnData object with n_obs × n_vars = 5569 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'A11': AnnData object with n_obs × n_vars = 10021 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'G10': AnnData object with n_obs × n_vars = 4933 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'A2': AnnData object with n_obs × n_vars = 1527 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'D7': AnnData object with n_obs × n_vars = 14809 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'A5': AnnData object with n_obs × n_vars = 13708 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'F10': AnnData object with n_obs × n_vars = 7831 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'F2': AnnData object with n_obs × n_vars = 6176 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'C7': AnnData object with n_obs × n_vars = 8455 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'F5': AnnData object with n_obs × n_vars = 11771 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'B5': AnnData object with n_obs × n_vars = 4934 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'H11': AnnData object with n_obs × n_vars = 1351 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'G7': AnnData object with n_obs × n_vars = 10780 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'B2': AnnData object with n_obs × n_vars = 1547 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'H8': AnnData object with n_obs × n_vars = 8480 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'G11': AnnData object with n_obs × n_vars = 9746 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'A10': AnnData object with n_obs × n_vars = 9008 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'D1': AnnData object with n_obs × n_vars = 7840 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'A4': AnnData object with n_obs × n_vars = 13389 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'D6': AnnData object with n_obs × n_vars = 6286 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'A3': AnnData object with n_obs × n_vars = 14170 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'E3': AnnData object with n_obs × n_vars = 3664 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers',
#  'E4': AnnData object with n_obs × n_vars = 11006 × 40
#      obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'imageid'
#      uns: 'all_markers'}

# %%
#
# Read in TMA metadata.
#
metadata_df = pd.read_csv('./metadata.tsv', sep='\t')
metadata_df
# Out:
#    Core            Subtype
# 0    G3               TNBC
# 1    G7               TNBC
# 2    F9               TNBC
# 3    F1               TNBC
# 4    E6               TNBC
# 5    A8               TNBC
# 6    A1          Luminal A
# 7    G5          Luminal A
# 8    E4          Luminal A
# 9    H4  Luminal B Her2Pos
# 10   B3  Luminal B Her2Pos
# 11  C10  Luminal B Her2Pos
# 12   A4  Luminal B Her2Neg
# 13   B6  Luminal B Her2Neg
# 14   G1  Luminal B Her2Neg
# 15   G6  Luminal B Her2Neg
# 16   E5  Luminal B Her2Neg

# %%
#
# Create single data frame with cell features and metadata.
#

# Select cores that are in the metadata.
selected_adatas = {key: value for key, value in adatas.items() if key in metadata_df['Core'].values}
selected_adatas.keys()

# Combine the selected cores into one anndata object.
combined = ad.concat(selected_adatas, label = 'Core')
# Out:
# /Users/goecksj/opt/miniconda3/envs/tma-ml/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
# Create final dataframe.
final_df = combined.to_df()

# Filter out Control/DNA/AF columns.
marker_cols = final_df.filter(regex="^(?!(Control|DNA|AF))").columns
final_df = final_df[marker_cols]

# Add Core column.
final_df['Core'] = combined.obs['Core']

# Join dataframe with metadata.
final_df = final_df.merge(metadata_df, left_on='Core', right_on='Core')
final_df
# Out:
#              CD3      pERK     Rad51     CCND1  Vimentin      aSMA      Ecad  \
# 0       1.108049  2.367280  1.205983  0.809805  0.643100  0.756149  0.904068
# 1       1.311849  2.748798  1.975927  0.784924  0.616813  1.014435  1.037699
# 2       1.032452  2.477824  2.406576  0.858549  0.979219  0.883893  1.461693
# 3       1.355602  2.269463  2.032605  0.832309  1.029909  1.421840  0.975202
# 4       1.179248  2.718190  2.304946  0.890247  0.758033  1.413838  1.545422
# ...          ...       ...       ...       ...       ...       ...       ...
# 250675  1.160113  2.319591  2.874407  0.757991  1.001444  2.052812  0.665222
# 250676  0.984769  2.487343  2.914809  0.651790  0.523562  0.317693  0.631203
# 250677  1.866579  2.141912  2.754014  1.008417  1.665936  3.014499  0.756899
# 250678  1.634488  2.699897  2.714368  0.995328  1.882192  2.115073  0.735628
# 250679  0.847918  1.690545  2.186314  0.739837  0.627639  1.209750  0.608062
#
#               ER        PR      EGFR  ...      CK19      CK17  LaminABC  \
# 0       1.873106  0.628908  0.905082  ...  1.842349  0.957701  0.734693
# 1       2.009408  0.450378  0.720003  ...  1.765434  0.923039  0.716357
# 2       2.592998  0.725899  0.818180  ...  4.319531  0.956670  1.415923
# 3       2.062229  0.641186  0.830057  ...  2.202574  0.986778  1.890009
# 4       3.391289  0.808776  0.840453  ...  3.262141  0.965366  1.823325
# ...          ...       ...       ...  ...       ...       ...       ...
# 250675  1.729627  0.462439  0.635879  ...  1.543982  0.801783  0.790103
# 250676  1.288297  0.230164  0.623026  ...  1.679608  0.432103  0.764876
# 250677  1.953017  0.469935  0.750915  ...  2.000212  0.896921  1.071702
# 250678  1.905791  0.473499  0.783893  ...  2.055048  0.918055  1.057348
# 250679  1.521461  0.533107  0.581092  ...  1.540621  1.127921  0.669289
#
#               AR      H2Ax      PCNA     PanCK      CD31  Core    Subtype
# 0       1.192826  1.014207  1.136202  1.540347  1.503884    G5  Luminal A
# 1       0.900161  0.728166  1.100546  1.165204  1.135478    G5  Luminal A
# 2       1.038165  0.871665  1.171252  4.410381  1.246464    G5  Luminal A
# 3       1.013757  0.990621  1.184966  2.222565  1.360663    G5  Luminal A
# 4       1.305266  0.948487  1.754226  3.625247  1.270104    G5  Luminal A
# ...          ...       ...       ...       ...       ...   ...        ...
# 250675  0.680631  0.977413  0.647092  0.560885  1.197684    E4  Luminal A
# 250676  0.607900  0.565372  0.688264  0.930430  0.722552    E4  Luminal A
# 250677  0.903956  1.000271  0.991021  1.363368  1.348060    E4  Luminal A
# 250678  1.034916  1.025777  1.059736  1.173739  1.310694    E4  Luminal A
# 250679  0.664480  1.040639  0.656188  0.766979  1.337307    E4  Luminal A
#
# [250680 rows x 26 columns]

# %%
# Write dataframe to file.
final_df.to_csv('./tma_single_cell.tsv', index=False, sep='\t')
